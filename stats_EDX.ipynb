# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Fdata= np.loadtxt("c5_4_Fmap.txt")
Kdata= np.load("c5_4_Kmap.npy")
eimg= np.load("c5_4_edx_data_to_signal.npy")

# %%
nFdata= np.reshape(Fdata,(4096,1))
#nFdata.shape
plt.plot(nFdata,'.')

# %%
neimg= np.reshape(eimg,(4096,2048))
neimg(1:end,1)
#plt.plot(neimg[1],'.')
# Out:
#   File "<ipython-input-87-cb8e1b17934b>", line 2
#     neimg(1:end,1)
#            ^
# SyntaxError: invalid syntax

# %%
plt.figure(1)
plt.plot(nFdata,neimg,'b.')
plt.xlabel('Fluorine Concentration',fontsize=20)
plt.ylabel('Total Intensity',fontsize=20)
plt.title('Image Intensity vs. [F]',fontsize=24)
plt.tick_params(labelsize=14)
#axes = plt.gca()
#axes.set_xlim([0,150])
#axes.set_ylim([-5,65])

# %%
#nFdata
d=neimg[0]

# %%
#x=np.linspace(0,150,150)
b=np.array(nFdata)
c=b.ravel()
d=np.array(neimg)
e=d.ravel()
np.savetxt("Farray.txt",c)
np.savetxt("Eimgarray.txt",e)
#y=np.polyfit(c,e,1)

# %%
plt.figure(2)
plt.plot(Kdata,eimg[3],'b.')
plt.xlabel('Potassium Concentration',fontsize=20)
plt.ylabel('Total Intensity',fontsize=20)
plt.title('Image Intensity vs. [K]',fontsize=24)
plt.tick_params(labelsize=14)

# %%
bin=np.zeros(64,64)

for p=1:64
    for n=1:64
        bin(n,p)= mean(eimg(n,p,l))
# Out:
# (64, 64, 2048)

# %%
np.corrcoef(nFdata[0],neimg[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-592b8fbd840a> in <module>()
# ----> 1 np.corrcoef(nFdata[0],neimg[0])
#
# C:\Users\Tara\Anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2993         warnings.warn('bias and ddof have no effect and are deprecated',
#    2994                       DeprecationWarning, stacklevel=2)
# -> 2995     c = cov(x, y, rowvar)
#    2996     try:
#    2997         d = diag(c)
#
# C:\Users\Tara\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2863         if rowvar == 0 and y.shape[0] != 1:
#    2864             y = y.T
# -> 2865         X = np.vstack((X, y))
#    2866
#    2867     if ddof is None:
#
# C:\Users\Tara\Anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     232
#     233     """
# ...
